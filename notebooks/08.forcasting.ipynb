# %% [markdown]
# ### Time Series Demand & Complaint Prediction Using Prophet
#
# To predict future values based on historical patterns.We use Prophet tovpredict what sentiment trends and complaint volumes will look like in the future like daily negative review count,transaction complaint volume,fraud complaints.
#
# To avoid repeating forecasting code multiple times, reusable Prophet functions are created for:
# - preparing monthly time-series data,
# - training Prophet models,
# - generating future forecasts,
# - and plotting predictions.
#
# This improves code readability, modularity, and scalability across different fintech complaint categories.

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd

from prophet import Prophet

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
cleaned_df = pd.read_csv('cleaned_data.csv', keep_default_na=False)
cleaned_df.head()
# Out:
#                                reviewId  \
# 0  695de54e-4b85-4669-ae8c-ad2fdf16667e
# 1  acd5c061-de13-474b-8645-f628044f2a50
# 2  6f9f52e9-0a00-4f70-a1cc-7687f28465a3
# 3  4a605b22-efc1-4641-b79e-e166b4a7b2e4
# 4  fd284f23-d966-4be5-b421-a1f0e14c1e13
#
#                                              content  score  thumbsUpCount  \
# 0  The app still has issues on OTP, because I hav...      1              0
# 1  si everytime nitakuwa na bundles za ku check m...      2              0
# 2  this is the stupidest app ever from saf. the w...      1              0
# 3  Life must go on without this useless app. It u...      1              0
# 4                            the upgrade is terrible      1              0
#
#                     at appVersion app_name sentiment  with_emojis  \
# 0  2026-05-11 11:38:40      5.1.7    mpesa  negative        False
# 1  2026-05-11 11:22:24      5.1.1    mpesa  negative        False
# 2  2026-05-11 11:16:47      5.1.7    mpesa  negative        False
# 3  2026-05-11 11:01:23     1.14.2    mpesa  negative        False
# 4  2026-05-11 10:45:52    Unknown    mpesa  negative        False
#
#                                         cleaned_text  ...  \
# 0  the app still has issues on otp because i have...  ...
# 1  si everytime nitakuwa na bundles za ku check m...  ...
# 2  this is the stupidest app ever from saf the worst  ...
# 3  life must go on without this useless app it us...  ...
# 4                            the upgrade is terrible  ...
#
#                                  tokens_no_stopwords  \
# 0  ['still', 'issues', 'otp', 'havent', 'received...
# 1  ['si', 'everytime', 'nitakuwa', 'na', 'bundles...
# 2              ['stupidest', 'ever', 'saf', 'worst']
# 3  ['life', 'must', 'go', 'without', 'useless', '...
# 4                            ['upgrade', 'terrible']
#
#                                    meaningful_tokens  \
# 0  ['still', 'issues', 'otp', 'havent', 'received...
# 1  ['everytime', 'nitakuwa', 'bundles', 'check', ...
# 2              ['stupidest', 'ever', 'saf', 'worst']
# 3  ['life', 'must', 'without', 'useless', 'used',...
# 4                            ['upgrade', 'terrible']
#
#                                       stemmed_tokens  \
# 0  ['still', 'issu', 'otp', 'havent', 'receiv', '...
# 1  ['everytim', 'nitakuwa', 'bundl', 'check', 'nu...
# 2              ['stupidest', 'ever', 'saf', 'worst']
# 3  ['life', 'must', 'without', 'useless', 'use', ...
# 4                              ['upgrad', 'terribl']
#
#                                    lemmatized_tokens  \
# 0  ['still', 'issue', 'otp', 'havent', 'received'...
# 1  ['everytime', 'nitakuwa', 'bundle', 'check', '...
# 2              ['stupidest', 'ever', 'saf', 'worst']
# 3  ['life', 'must', 'without', 'useless', 'used',...
# 4                            ['upgrade', 'terrible']
#
#                                       processed_text sentiment_label  \
# 0  still issue otp havent received otp login trie...        negative
# 1  everytime nitakuwa bundle check number try fix...        negative
# 2                           stupidest ever saf worst        negative
# 3  life must without useless used work well data ...        negative
# 4                                   upgrade terrible        negative
#
#   complaint_label fraud_indicator review_length word_count
# 0       app_issue               0           173         26
# 1         general               0            95         16
# 2         general               0            24          4
# 3         general               0            64         12
# 4         general               0            16          2
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Forecasting Negative Complaint Volume
#
# This forecasting model predicts future negative fintech complaint trends using Facebook Prophet.
#
# The goal is to identify future spikes in customer dissatisfaction and financial distress.

# %%
# Convert the 'at' column to datetime format
cleaned_df['at'] = pd.to_datetime(cleaned_df['at'])

# %%
def prophet_forecast(
    data,
    date_col,
    title,
    periods=6
):

    # Monthly aggregation
    ts = (
        data
        .groupby(
            pd.Grouper(
                key=date_col,
                freq='ME'
            )
        )
        .size()
        .reset_index(name='y')
        .rename(columns={date_col: 'ds'})
    )

    # Train model
    model = Prophet()

    model.fit(ts)

    # Future prediction
    future = model.make_future_dataframe(
        periods=periods,
        freq='ME'
    )

    forecast = model.predict(future)

    # Plot
    model.plot(forecast)

    plt.title(title)

    plt.show()

    return forecast

def prophet_forecast(
    data,
    date_col,
    title,
    periods=6
):

    # Monthly aggregation
    ts = (
        data
        .groupby(
            pd.Grouper(
                key=date_col,
                freq='ME'
            )
        )
        .size()
        .reset_index(name='y')
        .rename(columns={date_col: 'ds'})
    )

    # Train model
    model = Prophet()

    model.fit(ts)

    # Future prediction
    future = model.make_future_dataframe(
        periods=periods,
        freq='ME'
    )

    forecast = model.predict(future)

    # Plot
    model.plot(forecast)

    plt.title(title)

    plt.show()

    return forecast

# %% [markdown]
# Forecast Negative Complaints

# %%
negative_forecast = prophet_forecast(
    data=cleaned_df[cleaned_df['sentiment_label'] == 'negative'],
    date_col='at',
    title='Forecasted Negative Complaints'
)
# Out:
# 01:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 01:26:54 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# The forecast shows an upward trend in complaint volume over time, suggesting that user dissatisfaction and financial distress may continue increasing if service issues are not addressed.

# %% [markdown]
# Forecast Fraud Complaints

# %%
fraud_forecast = prophet_forecast(
    data=cleaned_df[cleaned_df['fraud_indicator'] == 1],
    date_col='at',
    title='Predicted Fraud Complaint Spikes'
)
# Out:
# 01:26:55 - cmdstanpy - INFO - Chain [1] start processing
# 01:26:56 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# The fraud forecasting model predicts future increases in fraud-related complaints, suggesting elevated consumer risk and the need for proactive monitoring by fintech providers and regulators.

# %% [markdown]
# Forecast M-Pesa Complaints

# %%
mpesa_forecast = prophet_forecast(
    data=cleaned_df[cleaned_df['app_name'] == 'mpesa'],
    date_col='at',
    title='M-Pesa Complaint Forecast'
)
# Out:
# 01:26:57 - cmdstanpy - INFO - Chain [1] start processing
# 01:26:57 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# Forecast Tala Complaints

# %%
tala_forecast = prophet_forecast(
    data=cleaned_df[cleaned_df['app_name'] == 'tala'],
    date_col='at',
    title='Tala Complaint Forecast'
)
# Out:
# 01:26:58 - cmdstanpy - INFO - Chain [1] start processing
# 01:27:00 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# #### Business Insight
#
# The forecasting analysis suggests that complaint activity within Kenya’s mobile money ecosystem may continue increasing over time, particularly for high-usage platforms such as M-Pesa. Fraud-related complaint spikes also appear periodically, indicating the need for proactive fraud monitoring and consumer protection interventions.
#
# These findings demonstrate that fintech complaint data can be used not only for real-time sentiment analysis, but also for predictive risk monitoring and early warning systems.
